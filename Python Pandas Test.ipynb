# %%
import pandas as pd
import numpy as np
movies_path ='imdb_1000.csv'
orders_path = 'chipotle.tsv'
ufo_path = 'ufo.csv'
drinks_path = 'drinks.csv'

# %%
# read a first few lines of orders dataset
movies=pd.read_csv(movies_path)
ufo=pd.read_csv(ufo_path)
#drinks=pd.read_csv(drinks_path)
#op=pd.read_tsv(orders_path)
movies.head()
# Out:
#    star rating                     title content rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# select the 'City' column from ufo dataset using bracket notation
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['City']
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
# select the 'City' column from ufo dataset using dot notation
ufo.ix[:,'City']
# Out:
# /Users/apple/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# ...

# %%
ufo.head(1)
# Out:
#      City Colors Reported Shape Reported State            Time
# 0  Ithaca             NaN       TRIANGLE    NY  6/1/1930 22:00

# %%
# create a new 'Location' using city and state column with coma as delimiter
#ufo['Location']=ufo
# Out:
# <bound method NDFrame.describe of                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
# Calculate summary statistics of movies dataset
movies.describe()
# Out:
#        star rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
# check number of rows and columns of movies dataset
movies.shape
# Out:
# (979, 6)

# %%
# check data type of each column in movies dataset
movies.dtypes
# Out:
# star rating       float64
# title              object
# content rating     object
# genre              object
# duration            int64
# actors list        object
# dtype: object

# %%
# Describe categorical columns only in movies dataset
movies.describe()
# Out:
#        star rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies
# Out:
#      star rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
# How do I rename columns of ufo using the 'rename' method using dictionary
change_dict = {'Colors Reported':'Colors_Reported', 'Shape Reported':'Shape_Reported'}
ufo1=ufo.rename_axis(change_dict,axis='columns')

# %%
# Replace all spaces with underscores in the column names by using the 'str.replace' method
ufo1.head(1)
# Out:
#      City Colors_Reported Shape_Reported State            Time
# 0  Ithaca             NaN       TRIANGLE    NY  6/1/1930 22:00

# %%
# How do I remove a particular column from a ufo dataset
del ufo1['Colors_Reported']

# %%
# How do I remove multiple columns from a ufo dataset
ufo1.drop(['Colors_Reported','Shape_Reported'],axis=1)
# Out:
#                        City State              Time
# 0                    Ithaca    NY    6/1/1930 22:00
# 1               Willingboro    NJ   6/30/1930 20:00
# 2                   Holyoke    CO   2/15/1931 14:00
# 3                   Abilene    KS    6/1/1931 13:00
# 4      New York Worlds Fair    NY   4/18/1933 19:00
# 5               Valley City    ND   9/15/1934 15:30
# 6               Crater Lake    CA    6/15/1935 0:00
# 7                      Alma    MI    7/15/1936 0:00
# 8                   Eklutna    AK  10/15/1936 17:00
# 9                   Hubbard    OR    6/15/1937 0:00
# 10                  Fontana    CA   8/15/1937 21:00
# 11                 Waterloo    AL    6/1/1939 20:00
# 12                   Belton    SC   6/30/1939 20:00
# 13                   Keokuk    IA     7/7/1939 2:00
# 14                Ludington    MI    6/1/1941 13:00
# 15              Forest Home    CA    7/2/1941 11:30
# 16              Los Angeles    CA    2/25/1942 0:00
# ...

# %%
# sort movies dataset on duration column in descending order instead
movies.sort_values(by='duration',ascending=False)
# Out:
#      star rating                                          title  \
# 476          7.8                                         Hamlet
# 157          8.2                             Gone with the Wind
# 78           8.4                    Once Upon a Time in America
# 142          8.3              Lagaan: Once Upon a Time in India
# 445          7.9                           The Ten Commandments
# 85           8.4                             Lawrence of Arabia
# 204          8.1                                        Ben-Hur
# 17           8.7                                  Seven Samurai
# 767          7.6                It's a Mad, Mad, Mad, Mad World
# 630          7.7                                      Malcolm X
# 7            8.9  The Lord of the Rings: The Return of the King
# 2            9.1                         The Godfather: Part II
# 335          8.0                                 Doctor Zhivago
# 385          8.0                                      Spartacus
# ...

# %%
# filter movies dataset with duration >=200 minutes
movies[movies['duration'] > 200]
# Out:
#      star rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
# filter for movies having genre  'Crime', 'Drama', 'Action'
#movies.isin(['Crime', 'Drama', 'Action'])
movies[(movies['genre']=='Crime')| (movies['genre']=='Drama')| (movies['genre']=='Action')]
# Out:
#      star rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# 16           8.7                  One Flew Over the Cuckoo's Nest
# 17           8.7                                    Seven Samurai
# 19           8.7                                        Star Wars
# ...
